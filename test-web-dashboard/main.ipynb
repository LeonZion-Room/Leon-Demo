# %%
# !python -m venv .venv

# %%
# !.venv\Scripts\pip install streamlit  -i https://mirrors.aliyun.com/pypi/simple/
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#      ---------------------------------------- 0.1/10.2 MB 2.3 MB/s eta 0:00:05
#       --------------------------------------- 0.2/10.2 MB 2.2 MB/s eta 0:00:05
#       --------------------------------------- 0.2/10.2 MB 1.8 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/10.2 MB 1.8 MB/s eta 0:00:06
#      - -------------------------------------- 0.4/10.2 MB 1.8 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/10.2 MB 2.0 MB/s eta 0:00:05
#      -- ------------------------------------- 0.6/10.2 MB 2.0 MB/s eta 0:00:05
#      -- ------------------------------------- 0.6/10.2 MB 1.7 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/10.2 MB 1.8 MB/s eta 0:00:06
#      --- ------------------------------------ 0.8/10.2 MB 1.8 MB/s eta 0:00:06
# ...
